# %%
# This code automatically updates the core thickness in different regions and runs the job.
# Returns the odb files.
for i,x in enumerate([[0.01, 0.01, 0.01, 0.01386045152321463, 0.045743314549327126]]):
    job_name='FINAL'+str(i+1)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A1'].deletePlies(
    )
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A1'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1', region=Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#140 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A1'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy8', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#140 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A1'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy7', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#140 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A1'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy6', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#140 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A1'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='balsa', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=0.0, plyName='Ply-1-Copy5', region=Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#140 ]', ), )), suppressed=False, thickness=x[0], thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A1'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy4', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#140 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A1'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy3', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#140 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A1'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy2', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#140 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A1'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy1', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#140 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A2'].deletePlies(
    )
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A2'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1', region=Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#2010 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A2'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy8', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#2010 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A2'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy7', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#2010 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A2'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy6', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#2010 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A2'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='balsa', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=0.0, plyName='Ply-1-Copy5', region=Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#2010 ]', ), )), suppressed=False, thickness=x[1], thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A2'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy4', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#2010 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A2'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy3', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#2010 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A2'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy2', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#2010 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A2'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy1', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#2010 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A3'].deletePlies(
    )
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A3'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1', region=Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#204 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A3'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy8', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#204 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A3'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy7', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#204 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A3'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy6', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#204 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A3'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='balsa', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=0.0, plyName='Ply-1-Copy5', region=Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#204 ]', ), )), suppressed=False, thickness=x[2], thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A3'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy4', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#204 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A3'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy3', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#204 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A3'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy2', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#204 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A3'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy1', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#204 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A4'].deletePlies(
    )
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A4'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1', region=Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#9 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A4'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy9', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#9 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A4'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy8', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#9 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A4'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy7', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#9 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A4'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='balsa', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=0.0, plyName='Ply-1-Copy6', region=Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#9 ]', ), )), suppressed=False, thickness=x[3], thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A4'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy5', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#9 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A4'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy4', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#9 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A4'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy3', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#9 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A4'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy2', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#9 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A5'].deletePlies(
    )
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A5'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1', region=Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#4400 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A5'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy8', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#4400 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A5'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy7', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#4400 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A5'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy6', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#4400 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A5'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='balsa', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=0.0, plyName='Ply-1-Copy5', region=Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#4400 ]', ), )), suppressed=False, thickness=x[4], thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A5'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy4', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#4400 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A5'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy3', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#4400 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A5'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy2', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#4400 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['A5'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy1', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#4400 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['SL1'].deletePlies(
    )
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['SL1'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1', region=Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#800 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['SL1'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy9', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#800 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['SL1'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy8', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#800 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['SL1'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy7', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#800 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['SL1'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='balsa', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=0.0, plyName='Ply-1-Copy7-Copy1', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#800 ]', ), )), suppressed=False, thickness=x[0], thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['SL2'].deletePlies(
    )
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['SL2'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1', region=Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#20 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['SL2'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy9', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#20 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['SL2'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy8', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#20 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['SL2'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy7', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#20 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['SL2'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='balsa', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=0.0, plyName='Ply-1-Copy7-Copy1', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#20 ]', ), )), suppressed=False, thickness=x[1], thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['SL3'].deletePlies(
    )
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['SL3'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1', region=Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#2 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['SL3'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy8', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#2 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['SL3'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy7', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#2 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['SL3'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy6', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#2 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['SL3'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='balsa', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=0.0, plyName='Ply-1-Copy6-Copy1', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#2 ]', ), )), suppressed=False, thickness=x[2], thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['SL4'].deletePlies(
    )
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['SL4'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1', region=Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#80 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['SL4'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy9', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#80 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['SL4'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy8', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#80 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['SL4'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy7', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#80 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['SL4'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='balsa', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=0.0, plyName='Ply-1-Copy7-Copy1', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#80 ]', ), )), suppressed=False, thickness=x[3], thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['SL5'].deletePlies(
    )
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['SL5'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1', region=Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#1000 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['SL5'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy8', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#1000 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['SL5'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy7', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#1000 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['SL5'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy6', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#1000 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['with spline one done'].compositeLayups['SL5'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='balsa', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=0.0, plyName='Ply-1-Copy6-Copy1', region=
    Region(
    faces=mdb.models['Model-1'].parts['with spline one done'].faces.getSequenceFromMask(
    mask=('[#1000 ]', ), )), suppressed=False, thickness=x[4], thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp3'].compositeLayups['SR1'].deletePlies()
    mdb.models['Model-1'].parts['lp3'].compositeLayups['SR1'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='balsa', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=0.0, plyName='Ply-1-Copy5', region=Region(
    faces=mdb.models['Model-1'].parts['lp3'].faces.getSequenceFromMask(mask=(
    '[#8 ]', ), )), suppressed=False, thickness=x[0], thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp3'].compositeLayups['SR1'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy4', region=
    Region(faces=mdb.models['Model-1'].parts['lp3'].faces.getSequenceFromMask(
    mask=('[#8 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp3'].compositeLayups['SR1'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy3', region=
    Region(faces=mdb.models['Model-1'].parts['lp3'].faces.getSequenceFromMask(
    mask=('[#8 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp3'].compositeLayups['SR1'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy2', region=
    Region(faces=mdb.models['Model-1'].parts['lp3'].faces.getSequenceFromMask(
    mask=('[#8 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp3'].compositeLayups['SR1'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy1', region=
    Region(faces=mdb.models['Model-1'].parts['lp3'].faces.getSequenceFromMask(
    mask=('[#8 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp3'].compositeLayups['SR2'].deletePlies()
    mdb.models['Model-1'].parts['lp3'].compositeLayups['SR2'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='balsa', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=0.0, plyName='Ply-1-Copy5', region=Region(
    faces=mdb.models['Model-1'].parts['lp3'].faces.getSequenceFromMask(mask=(
    '[#4 ]', ), )), suppressed=False, thickness=x[1], thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp3'].compositeLayups['SR2'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy4', region=
    Region(faces=mdb.models['Model-1'].parts['lp3'].faces.getSequenceFromMask(
    mask=('[#4 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp3'].compositeLayups['SR2'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy3', region=
    Region(faces=mdb.models['Model-1'].parts['lp3'].faces.getSequenceFromMask(
    mask=('[#4 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp3'].compositeLayups['SR2'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy2', region=
    Region(faces=mdb.models['Model-1'].parts['lp3'].faces.getSequenceFromMask(
    mask=('[#4 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp3'].compositeLayups['SR2'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy1', region=
    Region(faces=mdb.models['Model-1'].parts['lp3'].faces.getSequenceFromMask(
    mask=('[#4 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp3'].compositeLayups['SR3'].deletePlies()
    mdb.models['Model-1'].parts['lp3'].compositeLayups['SR3'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='balsa', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=0.0, plyName='Ply-1-Copy5', region=Region(
    faces=mdb.models['Model-1'].parts['lp3'].faces.getSequenceFromMask(mask=(
    '[#2 ]', ), )), suppressed=False, thickness=x[2], thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp3'].compositeLayups['SR3'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy4', region=
    Region(faces=mdb.models['Model-1'].parts['lp3'].faces.getSequenceFromMask(
    mask=('[#2 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp3'].compositeLayups['SR3'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy3', region=
    Region(faces=mdb.models['Model-1'].parts['lp3'].faces.getSequenceFromMask(
    mask=('[#2 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp3'].compositeLayups['SR3'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy2', region=
    Region(faces=mdb.models['Model-1'].parts['lp3'].faces.getSequenceFromMask(
    mask=('[#2 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp3'].compositeLayups['SR3'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy1', region=
    Region(faces=mdb.models['Model-1'].parts['lp3'].faces.getSequenceFromMask(
    mask=('[#2 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp3'].compositeLayups['SR4'].deletePlies()
    mdb.models['Model-1'].parts['lp3'].compositeLayups['SR4'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='balsa', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=0.0, plyName='Ply-1-Copy5', region=Region(
    faces=mdb.models['Model-1'].parts['lp3'].faces.getSequenceFromMask(mask=(
    '[#1 ]', ), )), suppressed=False, thickness=x[3], thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp3'].compositeLayups['SR4'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy4', region=
    Region(faces=mdb.models['Model-1'].parts['lp3'].faces.getSequenceFromMask(
    mask=('[#1 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp3'].compositeLayups['SR4'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy3', region=
    Region(faces=mdb.models['Model-1'].parts['lp3'].faces.getSequenceFromMask(
    mask=('[#1 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp3'].compositeLayups['SR4'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy2', region=
    Region(faces=mdb.models['Model-1'].parts['lp3'].faces.getSequenceFromMask(
    mask=('[#1 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp3'].compositeLayups['SR4'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy1', region=
    Region(faces=mdb.models['Model-1'].parts['lp3'].faces.getSequenceFromMask(
    mask=('[#1 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp3'].compositeLayups['SR5'].deletePlies()
    mdb.models['Model-1'].parts['lp3'].compositeLayups['SR5'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='balsa', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=0.0, plyName='Ply-1-Copy5', region=Region(
    faces=mdb.models['Model-1'].parts['lp3'].faces.getSequenceFromMask(mask=(
    '[#10 ]', ), )), suppressed=False, thickness=x[4], thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp3'].compositeLayups['SR5'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy4', region=
    Region(faces=mdb.models['Model-1'].parts['lp3'].faces.getSequenceFromMask(
    mask=('[#10 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp3'].compositeLayups['SR5'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy3', region=
    Region(faces=mdb.models['Model-1'].parts['lp3'].faces.getSequenceFromMask(
    mask=('[#10 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp3'].compositeLayups['SR5'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy2', region=
    Region(faces=mdb.models['Model-1'].parts['lp3'].faces.getSequenceFromMask(
    mask=('[#10 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp3'].compositeLayups['SR5'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy1', region=
    Region(faces=mdb.models['Model-1'].parts['lp3'].faces.getSequenceFromMask(
    mask=('[#10 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D1'].deletePlies()
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D1'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1', region=Region(
    faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(mask=(
    '[#10 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D1'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy8', region=
    Region(faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(
    mask=('[#10 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D1'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy7', region=
    Region(faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(
    mask=('[#10 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D1'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy6', region=
    Region(faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(
    mask=('[#10 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D1'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='balsa', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=0.0, plyName='Ply-1-Copy5', region=Region(
    faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(mask=(
    '[#10 ]', ), )), suppressed=False, thickness=x[0], thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D1'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy4', region=
    Region(faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(
    mask=('[#10]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D1'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy3', region=
    Region(faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(
    mask=('[#10 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D1'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy2', region=
    Region(faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(
    mask=('[#10 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D1'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy1', region=
    Region(faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(
    mask=('[#10 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D2'].deletePlies()
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D2'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1', region=Region(
    faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(mask=(
    '[#8 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D2'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy8', region=
    Region(faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(
    mask=('[#8 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D2'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy7', region=
    Region(faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(
    mask=('[#8 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D2'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy6', region=
    Region(faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(
    mask=('[#8 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D2'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='balsa', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=0.0, plyName='Ply-1-Copy5', region=Region(
    faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(mask=(
    '[#8 ]', ), )), suppressed=False, thickness=x[1], thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D2'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy4', region=
    Region(faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(
    mask=('[#8 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D2'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy3', region=
    Region(faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(
    mask=('[#8 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D2'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy2', region=
    Region(faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(
    mask=('[#8 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D2'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy1', region=
    Region(faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(
    mask=('[#8 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D3'].deletePlies()
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D3'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1', region=Region(
    faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(mask=(
    '[#4 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D3'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy9', region=
    Region(faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(
    mask=('[#4 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D3'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy8', region=
    Region(faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(
    mask=('[#4 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D3'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy7', region=
    Region(faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(
    mask=('[#4 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D3'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='balsa', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=0.0, plyName='Ply-1-Copy6', region=Region(
    faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(mask=(
    '[#4 ]', ), )), suppressed=False, thickness=x[2], thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D3'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy5', region=
    Region(faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(
    mask=('[#4 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D3'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy4', region=
    Region(faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(
    mask=('[#4 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D3'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy3', region=
    Region(faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(
    mask=('[#4 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D3'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy2', region=
    Region(faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(
    mask=('[#4 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D4'].deletePlies()
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D4'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1', region=Region(
    faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(mask=(
    '[#2 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D4'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy8', region=
    Region(faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(
    mask=('[#2 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D4'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy7', region=
    Region(faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(
    mask=('[#2 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D4'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy6', region=
    Region(faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(
    mask=('[#2 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D4'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='balsa', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=0.0, plyName='Ply-1-Copy5', region=Region(
    faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(mask=(
    '[#2 ]', ), )), suppressed=False, thickness=x[3], thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D4'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy4', region=
    Region(faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(
    mask=('[#2 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D4'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy3', region=
    Region(faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(
    mask=('[#2 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D4'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy2', region=
    Region(faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(
    mask=('[#2 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D4'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy1', region=
    Region(faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(
    mask=('[#2 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D5'].deletePlies()
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D5'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1', region=Region(
    faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(mask=(
    '[#1 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D5'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy9', region=
    Region(faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(
    mask=('[#1 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D5'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy8', region=
    Region(faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(
    mask=('[#1 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D5'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy7', region=
    Region(faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(
    mask=('[#1 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D5'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='balsa', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=0.0, plyName='Ply-1-Copy6', region=Region(
    faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(mask=(
    '[#1 ]', ), )), suppressed=False, thickness=x[4], thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D5'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy5', region=
    Region(faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(
    mask=('[#1 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D5'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy4', region=
    Region(faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(
    mask=('[#1 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D5'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy3', region=
    Region(faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(
    mask=('[#1 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp1'].compositeLayups['D5'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy2', region=
    Region(faces=mdb.models['Model-1'].parts['lp1'].faces.getSequenceFromMask(
    mask=('[#1 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D1'].deletePlies()
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D1'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1', region=Region(
    faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(mask=(
    '[#8 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D1'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy9', region=
    Region(faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(
    mask=('[#8 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D1'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy8', region=
    Region(faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(
    mask=('[#8 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D1'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy7', region=
    Region(faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(
    mask=('[#8 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D1'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='balsa', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=0.0, plyName='Ply-1-Copy6', region=Region(
    faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(mask=(
    '[#8 ]', ), )), suppressed=False, thickness=x[0], thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D1'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy5', region=
    Region(faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(
    mask=('[#8 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D1'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy4', region=
    Region(faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(
    mask=('[#8 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D1'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy3', region=
    Region(faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(
    mask=('[#8 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D1'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy2', region=
    Region(faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(
    mask=('[#8 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D2'].deletePlies()
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D2'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1', region=Region(
    faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(mask=(
    '[#4 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D2'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy8', region=
    Region(faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(
    mask=('[#4 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D2'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy7', region=
    Region(faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(
    mask=('[#4 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D2'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy6', region=
    Region(faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(
    mask=('[#4 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D2'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='balsa', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=0.0, plyName='Ply-1-Copy5', region=Region(
    faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(mask=(
    '[#4 ]', ), )), suppressed=False, thickness=x[1], thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D2'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy4', region=
    Region(faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(
    mask=('[#4 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D2'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy3', region=
    Region(faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(
    mask=('[#4 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D2'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy2', region=
    Region(faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(
    mask=('[#4 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D2'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy1', region=
    Region(faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(
    mask=('[#4 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D3'].deletePlies()
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D3'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1', region=Region(
    faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(mask=(
    '[#2 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D3'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy8', region=
    Region(faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(
    mask=('[#2 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D3'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy7', region=
    Region(faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(
    mask=('[#2 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D3'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy6', region=
    Region(faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(
    mask=('[#2 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D3'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='balsa', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=0.0, plyName='Ply-1-Copy5', region=Region(
    faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(mask=(
    '[#2 ]', ), )), suppressed=False, thickness=x[2], thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D3'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy4', region=
    Region(faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(
    mask=('[#2 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D3'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy3', region=
    Region(faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(
    mask=('[#2 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D3'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy2', region=
    Region(faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(
    mask=('[#2 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D3'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy1', region=
    Region(faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(
    mask=('[#2 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D4'].deletePlies()
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D4'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1', region=Region(
    faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(mask=(
    '[#1 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D4'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy8', region=
    Region(faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(
    mask=('[#1 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D4'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy7', region=
    Region(faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(
    mask=('[#1 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D4'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy6', region=
    Region(faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(
    mask=('[#1 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D4'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='balsa', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=0.0, plyName='Ply-1-Copy5', region=Region(
    faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(mask=(
    '[#1 ]', ), )), suppressed=False, thickness=x[3], thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D4'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy4', region=
    Region(faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(
    mask=('[#1 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D4'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy3', region=
    Region(faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(
    mask=('[#1 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D4'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy2', region=
    Region(faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(
    mask=('[#1 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D4'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy1', region=
    Region(faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(
    mask=('[#1 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D5'].deletePlies()
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D5'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1', region=Region(
    faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(mask=(
    '[#10 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D5'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy8', region=
    Region(faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(
    mask=('[#10 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D5'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy7', region=
    Region(faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(
    mask=('[#10 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D5'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy6', region=
    Region(faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(
    mask=('[#10 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D5'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='balsa', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=0.0, plyName='Ply-1-Copy5', region=Region(
    faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(mask=(
    '[#10 ]', ), )), suppressed=False, thickness=x[4], thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D5'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy4', region=
    Region(faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(
    mask=('[#10 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D5'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy3', region=
    Region(faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(
    mask=('[#10 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D5'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=45.0, plyName='Ply-1-Copy2', region=
    Region(faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(
    mask=('[#10 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.models['Model-1'].parts['lp2'].compositeLayups['D5'].CompositePly(
    additionalRotationField='', additionalRotationType=ROTATION_NONE, angle=0.0
    , axis=AXIS_3, material='carbon fiber', numIntPoints=3, orientationType=
    SPECIFY_ORIENT, orientationValue=-45.0, plyName='Ply-1-Copy1', region=
    Region(faces=mdb.models['Model-1'].parts['lp2'].faces.getSequenceFromMask(
    mask=('[#10 ]', ), )), suppressed=False, thickness=0.0003, thicknessType=
    SPECIFY_THICKNESS)
    mdb.Job(atTime=None, contactPrint=OFF, description='', echoPrint=OFF, 
    explicitPrecision=SINGLE, getMemoryFromAnalysis=True, historyPrint=OFF, 
    memory=90, memoryUnits=PERCENTAGE, model='Model-1', modelPrint=OFF, 
    multiprocessingMode=DEFAULT, name=job_name, nodalOutputPrecision=SINGLE, 
    numCpus=1, numGPUs=0, queue=None, resultsFormat=ODB, scratch='', type=
    ANALYSIS, userSubroutine='', waitHours=0, waitMinutes=0)
    mdb.jobs[job_name].submit(consistencyChecking=OFF)
    mdb.jobs[job_name].waitForCompletion()
